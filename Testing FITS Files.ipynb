# %%
import matplotlib.pyplot as plt
from astropy.io import fits
header = fits.getheader('./lab 3 linearity/bright_100s001.FIT')
data = fits.getdata('./lab 3 linearity/bright_100s001.FIT')

# %%
plt.imshow(data, vmin=10000, vmax=70000)
plt.colorbar()
plt.show()

# %%
plt.imshow(data, cmap="gray")
plt.colorbar()
plt.show()

# %%
data.size
# Out:
# 390150
